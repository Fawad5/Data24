# %% [markdown]
# # ***Weather In Pakistan (EDA)***
#
# ### ***Author :*** [***`Fawad Ali Shaikh`***](https://www.kaggle.com/fawadalishaikh)
#
# ### ***Date : `23-11-2024`***
# ### ***Dataset :*** [***`Rainfall in Pakistan`***](https://www.kaggle.com/datasets/zusmani/rainfall-in-pakistan)

# %% [markdown]
# ## ***Meta Data***
# ## ***`Context:`***
# *Like Every Countries in the world Pakistan is also suffering from Climate change. This dadtaset can help to learn from history and to make Future preparation.*
#
# ## ***`Content:`***
# *Dataset covers 116 years old rainfall in (mm).*

# %%
# import librairs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# To read csv from desktop
path = '/content/Rainfall_1901_2016_PAK.csv'

# %%
# Dispaly all rows and columns

pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
# Create Dataframe
df = pd.read_csv(path, encoding='latin-1')
df.head()
# Out:
#    Rainfall - (MM)   Year     Month
# 0          40.4258   1901   January
# 1          12.3022   1901  February
# 2          25.5119   1901     March
# 3          14.2942   1901     April
# 4          38.3046   1901       May

# %%
#shape

df.shape
# Out:
# (1392, 3)

# %%
print(f'The dataset has {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# The dataset has 1392 rows and 3 columns.

# %%
# Information about dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1392 entries, 0 to 1391
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rainfall - (MM)  1392 non-null   float64
#  1    Year            1392 non-null   int64
#  2   Month            1392 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 32.8+ KB

# %%
# Summmary

df.describe()
# Out:
#        Rainfall - (MM)         Year
# count      1392.000000  1392.000000
# mean         25.142392  1958.500000
# std          22.239632    33.497105
# min           0.105840  1901.000000
# 25%           9.586635  1929.750000
# 50%          19.653750  1958.500000
# 75%          33.753075  1987.250000
# max         154.055000  2016.000000

# %%
# Null Values

print(df.isnull().sum())
# Out:
# Rainfall - (MM)    0
#  Year              0
# Month              0
# dtype: int64

# %%
# Null Values
print(f'So we have no null values in the dataset.')
# Out:
# So we have no null values in the dataset.

# %%
# Range

print(f'This dataset covers Rainfall from {df[" Year"].min()} to {df[" Year"].max()}')
# Out:
# This dataset covers Rainfall from 1901 to 2016

# %%
# Maximun & Minimum Rainfall

print(f'This dataset anticipate Rainfall about {df["Rainfall - (MM)"].min()} mm to {df["Rainfall - (MM)"].max()} mm')
# Out:
# This dataset anticipate Rainfall about 0.10584 mm to 154.055 mm

# %%
# Columns in the dataset

df.columns
# Out:
# Index(['Rainfall - (MM)', ' Year', 'Month'], dtype='object')

# %%
# Unique values

df.nunique()
# Out:
# Rainfall - (MM)    1392
#  Year               116
# Month                12
# dtype: int64

# %%
df.head()
# Out:
#    Rainfall - (MM)   Year     Month
# 0          40.4258   1901   January
# 1          12.3022   1901  February
# 2          25.5119   1901     March
# 3          14.2942   1901     April
# 4          38.3046   1901       May

# %%
# bar plot of Rainfall & Month using seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x='Month', y='Rainfall - (MM)', data=df)
plt.title('Rainfall in Pakistan')
plt.xlabel('Month')
plt.ylabel('Rainfall - (MM)')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()  # Display the plot

# %%
# scatter plot of Rainfall & Year using seaborn
plt.figure(figsize=(12, 6))
sns.scatterplot(x=' Year', y='Rainfall - (MM)', data=df , hue="Rainfall - (MM)")
plt.title('Rainfall in Pakistan')
plt.xlabel('Year')
plt.ylabel('Rainfall - (MM)')
plt.show()  # Display the plot

# %%
# Box plot
plt.figure(figsize=(8, 6))
sns.boxplot( x='Rainfall - (MM)', data=df)
plt.title('Rainfall in Pakistan')
plt.xlabel('Month')
plt.ylabel('Rainfall - (MM)')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
print("So we have outliers")
# Out:
# So we have outliers

# %%
# Hist plot

plt.figure(figsize=(8 ,6))
sns.histplot(df['Rainfall - (MM)'], kde=True)
plt.title('Rainfall in Pakistan')
plt.xlabel('Month')
plt.ylabel('Rainfall - (MM)')
plt.show()

# %%
print("Not normalized OR Bell Curved")
# Out:
# Not normalized OR Bell Curved

# %% [markdown]
# ## ***Remove Outliers***

# %%
df['Rainfall - (MM)'].mean()
# Out:
# 25.142391681034486

# %%
df.shape
# Out:
# (1392, 3)

# %%
# remove outliers

df_clean = df[df['Rainfall - (MM)'] < 61]

# %%
df_clean.shape
# Out:
# (1294, 3)

# %%
df_clean['Rainfall - (MM)'].mean()
# Out:
# 20.656137805255025

# %%
# Box plot
plt.figure(figsize=(8, 6))
sns.boxplot( x='Rainfall - (MM)', data=df_clean)
plt.title('Rainfall in Pakistan')
plt.xlabel('Month')
plt.ylabel('Rainfall - (MM)')
# Out:
# Text(0, 0.5, 'Rainfall - (MM)')

# %%
# Hist plot

plt.figure(figsize=(8, 6))
sns.histplot(df_clean['Rainfall - (MM)'], kde=True)
plt.title('Rainfall in Pakistan')
plt.xlabel('Month')
plt.ylabel('Rainfall - (MM)')
plt.show()

# %% [markdown]
# ***Beforre Rewmoving Outliers***

# %%
df.boxplot(figsize=(8, 6))
# Out:
# <Axes: >

# %% [markdown]
# ### ***After Rewmoving Outliers***

# %%
df_clean.boxplot(figsize=(8, 6))
# Out:
# <Axes: >

# %%
df_clean.hist(figsize=(8, 6))
# Out:
# array([[<Axes: title={'center': 'Rainfall - (MM)'}>,
#         <Axes: title={'center': ' Year'}>]], dtype=object)

# %% [markdown]
# ## ***Relationship***

# %%
df_clean.dtypes
# Out:
# Rainfall - (MM)    float64
#  Year                int64
# Month               object
# dtype: object

# %%
# Convert object (months) to numeric

# Create a dictionary to map month names to numerical values
month_mapping = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

# Use the map function to apply the mapping to the 'Month' column
df_clean['Month'] = df_clean['Month'].map(month_mapping)

df_clean['Month'] = df_clean['Month'].astype("int64")
# Out:
# <ipython-input-79-07c2bc955c87>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Month'] = df_clean['Month'].map(month_mapping)
# <ipython-input-79-07c2bc955c87>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Month'] = df_clean['Month'].astype("int64")

# %%
# Let's check datatypes

df_clean.dtypes
# Out:
# Rainfall - (MM)    float64
#  Year                int64
# Month                int64
# dtype: object

# %%
# Realtionship between columns

df_clean.corr()
# Out:
#                  Rainfall - (MM)      Year     Month
# Rainfall - (MM)         1.000000  0.076819 -0.357460
#  Year                   0.076819  1.000000 -0.005951
# Month                  -0.357460 -0.005951  1.000000

# %%
# Heatmap

sns.heatmap(df_clean.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## ***`Conclusion:`***
# *More useful insights can be taken. If this dataset brings useful insights than upvote this.*
